# %% [markdown]
# # Mars Target Encyclopedia  - NER
# Thamme Gowda (Thamme.Gowda@jpl.nasa.gov)
#
# Named Entity Recognition / Sequence Tagging
# This notebook contains NER tagging using CRF suite
#
#
# ### Notes:
#  + Use python3, Reason: we need unicode strings, which is default in python3
#  + install Python-crfsuite
#  + Start CoreNLP Server

# %%
from itertools import chain
import nltk
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelBinarizer
import sklearn
import pycrfsuite
from pycorenlp import StanfordCoreNLP
from codecs import open as copen

import os, glob
import pickle

print(sklearn.__version__)
# Out:
# 0.18.1

# %%
#accept_labels = set(['Element', 'Mineral', 'Target', 'Material', 'Locality', 'Site'])
accept_labels = set(['Target'])


class BratToCRFSuitFeaturizer(object):
    def __init__(self, corenlp_url='http://localhost:9000', iob=False):
        '''
        Create Converter for converting brat annotations to Core NLP NER CRF
        classifier training data.
        @param corenlp_url: URL to corenlp server.
                To start the server checkout: http://stanfordnlp.github.io/CoreNLP/corenlp-server.html#getting-started
        @param iob: set 'True' for IOB encoding
        '''
        self.corenlp = StanfordCoreNLP(corenlp_url)
        self.iob = iob

    def convert(self, text_file, ann_file):
        text, tree = self.parse(text_file, ann_file)
        props = { 'annotators': 'tokenize,ssplit,lemma,pos', 'outputFormat': 'json'}
        if text[0].isspace():
            text = '.' + text[1:]
            # Reason: some tools trim/strip off the white spaces
            # which will mismatch the character offsets
        output = self.corenlp.annotate(text, properties=props)
        records = []
        for sentence in output['sentences']:
            sent_features = []
            continue_ann, continue_ann_en = None, None
            for tok in sentence['tokens']:
                begin, tok_end = tok['characterOffsetBegin'], tok['characterOffsetEnd']
                label = 'O'
                if begin in tree:
                    node = tree[begin]
                    if len(node) > 1:
                        print("WARN: multiple starts at ", begin, node)
                        if tok_end in node:
                            node = {tok_end: node[tok_end]} # picking one
                            print("Chose:", node)

                    ann_end, labels = list(node.items())[0]
                    if not len(labels) == 1:
                        print("WARN: Duplicate labels for token: %s, label:%s.\
                              Using the first one!" % (tok['word'], str(labels)))
                    if accept_labels is not None and labels[0] in accept_labels:
                        label = labels[0]

                    if tok_end == ann_end: # annotation ends where token ends
                        continue_ann = None
                    elif tok_end < ann_end and label != 'O':
                        #print("Continue for the next %d chars" % (ann_end - tok_end))
                        continue_ann = label
                        continue_ann_end = ann_end 
                    if label != 'O' and self.iob:
                        label = "B-" + label
                elif continue_ann is not None and tok_end <= continue_ann_end:
                    #print("Continuing the annotation %s, %d:%d %d]" % 
                    #(continue_ann, begin, tok_end, continue_ann_end))
                    label = continue_ann            # previous label is this label
                    if continue_ann_end == tok_end: # continuation ends here
                        #print("End")
                        continue_ann = None
                    if self.iob:
                        label = "I-" + label
                sent_features.append([tok['word'], tok['lemma'], tok['pos'], label])
            yield sent_features


    def parse(self, txt_file, ann_file):
        with copen(ann_file, 'r', encoding='utf-8') as ann_file:
            with copen(txt_file, 'r', encoding='utf-8') as text_file:
                texts = text_file.read()
            anns = map(lambda x: x.strip().split('\t'), ann_file)
            anns = filter(lambda x: len(x) > 2, anns)
            # FIXME: ignoring the annotatiosn which are complex

            anns = filter(lambda x: ';' not in x[1], anns)
            # FIXME: some annotations' spread have been split into many, separated by ; ignoring them

            def __parse_ann(ann):
                spec = ann[1].split()
                name = spec[0]
                markers = list(map(lambda x: int(x), spec[1:]))
                #t = ' '.join([texts[begin:end] for begin,end in zip(markers[::2], markers[1::2])])
                t = texts[markers[0]:markers[1]]
                if not t == ann[2]:
                    print("Error: Annotation mis-match, file=%s, ann=%s" % (txt_file, str(ann)))
                    return None
                return (name, markers, t)
            anns = map(__parse_ann, anns) # format
            anns = filter(lambda x: x, anns) # skip None

            # building a tree index for easy accessing
            tree = {}
            for entity_type, pos, name in anns:
                begin, end = pos[0], pos[1]
                if begin not in tree:
                    tree[begin] = {}
                node = tree[begin]
                if end not in node:
                    node[end] = []
                node[end].append(entity_type)

            # Re-read file in without decoding it
            text_file = copen(txt_file, 'r', encoding='utf-8')
            texts = text_file.read()
            text_file.close()
            return texts, tree

def scan_dir(dir_name):
    items = glob.glob(dir_name + "/*.ann")
    items = map(lambda f: (f, f.replace(".ann", ".txt")), items)
    return items

def preprocess_all(list_file, out_file):
    featzr = BratToCRFSuitFeaturizer(iob=True)
    tokenized = []
    with open(list_file) as f:
        examples = map(lambda l:l.strip().split(','), f.readlines())
    for txt_file, ann_file in examples:
        sents = featzr.convert(txt_file, ann_file)
        tokenized.append(list(sents))

    pickle.dump(tokenized, open(out_file, 'wb'))
    print("Dumped %d docs to %s" % (len(tokenized), out_file))

# %% [markdown]
# ## Parse and store the corpus
#
# In this step, we pass the text through CoreNLP pipeline, tokenize and POS tag them.
# In addition, we lookup the annotations file and match the target annotations with the token.
#
# Since this step is expensive, we store the results in pickle file, so that we can later load and resume our analysis for feature engineering.

# %%
p_dir = "/Users/thammegr/work/mte/data/newcorpus/workspace"
train_list = p_dir + "/train_62r15_685k14_384k15.list"
dev_list= p_dir + "/development.list"
test_list = p_dir + "/test.list"

train_corpus_file = 'mte-corpus-train.pickle'
preprocess_all(train_list, train_corpus_file)

# Test and Development set
dev_corpus_file = 'mte-corpus-dev.pickle'
preprocess_all(dev_list, dev_corpus_file)
test_corpus_file = 'mte-corpus-test.pickle'
preprocess_all(test_list, test_corpus_file)
# Out:
# WARN: multiple starts at  4183 {4224: ['Feature'], 4189: ['Element']}
# Chose: {4189: ['Element']}
# WARN: multiple starts at  5862 {5865: ['Material'], 5878: ['Feature']}
# WARN: multiple starts at  2533 {2553: ['Member'], 2546: ['Target']}
# Chose: {2546: ['Target']}
# WARN: multiple starts at  2648 {2659: ['Member'], 2652: ['Target']}
# Chose: {2652: ['Target']}
# WARN: multiple starts at  2733 {2750: ['Member'], 2743: ['Target']}
# Chose: {2743: ['Target']}
# WARN: multiple starts at  2816 {2832: ['Member'], 2825: ['Target']}
# Chose: {2825: ['Target']}
# WARN: multiple starts at  2944 {2965: ['Member'], 2958: ['Site']}
# WARN: multiple starts at  3052 {3065: ['Member'], 3058: ['Target']}
# Chose: {3058: ['Target']}
# WARN: multiple starts at  3270 {3281: ['Member'], 3274: ['Target']}
# Chose: {3274: ['Target']}
# WARN: multiple starts at  4443 {4459: ['Member'], 4452: ['Target']}
# Chose: {4452: ['Target']}
# WARN: multiple starts at  4743 {4749: ['Target'], 4758: ['Site']}
# Chose: {4749: ['Target']}
# WARN: multiple starts at  5464 {5481: ['Member'], 5474: ['Target']}
# Chose: {5474: ['Target']}
# WARN: multiple starts at  5550 {5569: ['Formation'], 5559: ['Locality']}
# Chose: {5559: ['Locality']}
# WARN: multiple starts at  818 {832: ['Region'], 826: ['Mineral']}
# Chose: {826: ['Mineral']}
# WARN: multiple starts at  1121 {1130: ['Mineral'], 1123: ['Element']}
# Chose: {1123: ['Element']}
# WARN: multiple starts at  1285 {1300: ['Member'], 1293: ['Target']}
# Chose: {1293: ['Target']}
# WARN: multiple starts at  1643 {1658: ['Member'], 1651: ['Target']}
# Chose: {1651: ['Target']}
# WARN: multiple starts at  3616 {3624: ['Target'], 3631: ['Member']}
# Chose: {3624: ['Target']}
# WARN: multiple starts at  4327 {4336: ['Element'], 4344: ['Mineral']}
# Chose: {4336: ['Element']}
# WARN: multiple starts at  2582 {2597: ['Member'], 2590: ['Target']}
# Chose: {2590: ['Target']}
# WARN: multiple starts at  4626 {4633: ['Element'], 4641: ['Mineral']}
# Chose: {4633: ['Element']}
# WARN: multiple starts at  1948 {1965: ['Member'], 1958: ['Target']}
# WARN: multiple starts at  1980 {1996: ['Member'], 1989: ['Target']}
# Chose: {1989: ['Target']}
# WARN: multiple starts at  2560 {2576: ['Member'], 2569: ['Target']}
# Chose: {2569: ['Target']}
# WARN: multiple starts at  3406 {3421: ['Member'], 3414: ['Target']}
# Chose: {3414: ['Target']}
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/lpsc15-C-raymond-sol1159/2452.txt, ann=['T42', 'Mineral 7565 7579', 'trachyandesite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/lpsc15-C-raymond-sol1159/2452.txt, ann=['T43', 'Mineral 7648 7656', 'basanite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/lpsc15-C-raymond-sol1159/2452.txt, ann=['T44', 'Mineral 8556 8570', 'trachyandesite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1103.txt, ann=['T5', 'Mineral 0 17', '1103.PDF']
# WARN: multiple starts at  4743 {4754: ['Mineral'], 4763: ['Mineral']}
# Chose: {4754: ['Mineral']}
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1142.txt, ann=['T3', 'Element 7237 7238', 'P']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1142.txt, ann=['T4', 'Element 7303 7304', 'P']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1142.txt, ann=['T5', 'Element 7605 7607', 'Cl']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1210.txt, ann=['T1', 'Element 6034 6035', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1231.txt, ann=['T2', 'Element 4265 4266', 'P']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1231.txt, ann=['T3', 'Element 4530 4531', 'B']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1231.txt, ann=['T4', 'Element 7318 7322', 'lead']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1231.txt, ann=['T5', 'Element 7861 7862', 'B']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1265.txt, ann=['T1', 'Element 9097 9101', 'lead']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T1', 'Element 3834 3835', 'K']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T2', 'Element 4021 4023', 'Pa']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T3', 'Element 4453 4454', 'K']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T4', 'Element 4472 4473', 'K']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T5', 'Element 6124 6128', 'lead']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T6', 'Element 9364 9365', 'V']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T7', 'Element 9521 9522', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T8', 'Element 9792 9793', 'B']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T9', 'Element 10145 10146', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1277.txt, ann=['T10', 'Element 10269 10270', 'F']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1315.txt, ann=['T10', 'Element 4374 4375', 'V']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1315.txt, ann=['T11', 'Element 6958 6959', 'F']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1315.txt, ann=['T12', 'Element 7041 7042', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1315.txt, ann=['T13', 'Element 7346 7347', 'V']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1315.txt, ann=['T14', 'Element 7495 7496', 'I']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1315.txt, ann=['T15', 'Element 7507 7508', 'W']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T3', 'Element 2438 2439', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T4', 'Element 3398 3399', 'K']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T5', 'Element 4073 4074', 'P']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T6', 'Element 4465 4466', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T7', 'Element 5509 5510', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T8', 'Element 5717 5724', 'Silicon']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T9', 'Element 5764 5765', 'K']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T10', 'Element 5939 5940', 'K']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T11', 'Element 6838 6839', 'I']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1324.txt, ann=['T12', 'Element 7071 7072', 'P']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1325.txt, ann=['T1', 'Element 7643 7645', 'Al']
# WARN: multiple starts at  3729 {3740: ['Mineral'], 3749: ['Mineral']}
# Chose: {3740: ['Mineral']}
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1430.txt, ann=['T1', 'Element 4112 4118', 'helium']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1430.txt, ann=['T2', 'Element 8879 8880', 'N']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1430.txt, ann=['T3', 'Element 9027 9028', 'P']
# WARN: multiple starts at  6375 {6386: ['Mineral'], 6395: ['Mineral']}
# Chose: {6386: ['Mineral']}
# WARN: multiple starts at  2752 {2763: ['Mineral'], 2772: ['Mineral']}
# Chose: {2763: ['Mineral']}
# WARN: multiple starts at  776 {787: ['Mineral'], 796: ['Mineral']}
# Chose: {787: ['Mineral']}
# WARN: multiple starts at  4116 {4125: ['Element'], 4134: ['Mineral']}
# Chose: {4125: ['Element']}
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1654.txt, ann=['T2', 'Element 3648 3650', 'Li']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1654.txt, ann=['T3', 'Element 9074 9076', 'Li']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1654.txt, ann=['T4', 'Element 9115 9117', 'Li']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1654.txt, ann=['T5', 'Element 9119 9120', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1654.txt, ann=['T6', 'Element 9130 9132', 'Li']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc14-text/1654.txt, ann=['T7', 'Mineral 7576 7587', 'plagioclase']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1065.txt, ann=['T1', 'Element 6733 6734', 'C']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1069.txt, ann=['T1', 'Element 7340 7341', 'F']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1093.txt, ann=['T2', 'Element 2117 2118', 'C']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1093.txt, ann=['T3', 'Element 3588 3590', 'Ra']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1093.txt, ann=['T4', 'Element 4126 4127', 'H']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1093.txt, ann=['T5', 'Element 4571 4572', 'H']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1093.txt, ann=['T6', 'Element 5508 5512', 'lead']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1102.txt, ann=['T1', 'Element 8212 8213', 'K']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1102.txt, ann=['T2', 'Element 8278 8279', 'I']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1102.txt, ann=['T3', 'Element 8291 8292', 'C']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1102.txt, ann=['T4', 'Element 8307 8308', 'K']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1102.txt, ann=['T5', 'Element 8364 8365', 'P']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1102.txt, ann=['T6', 'Element 8380 8381', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1102.txt, ann=['T7', 'Element 8489 8490', 'N']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1102.txt, ann=['T8', 'Element 8538 8539', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1102.txt, ann=['T9', 'Mineral 5079 5086', 'Hermite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1105.txt, ann=['T4', 'Mineral 0 18', '1105.PDF']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T5', 'Element 3030 3034', 'iron']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T6', 'Element 3196 3197', 'K']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T7', 'Element 4773 4777', 'iron']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T8', 'Element 6382 6386', 'iron']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T9', 'Element 6860 6864', 'iron']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T10', 'Element 6890 6894', 'iron']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T11', 'Element 7074 7078', 'iron']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T12', 'Element 8172 8176', 'iron']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T13', 'Element 8760 8761', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1151.txt, ann=['T14', 'Mineral 3071 3081', 'forsterite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1157.txt, ann=['T1', 'Element 5927 5928', 'F']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1157.txt, ann=['T2', 'Element 6070 6071', 'F']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T10', 'Element 5663 5664', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T11', 'Element 6666 6667', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T12', 'Element 6742 6743', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T13', 'Element 7064 7065', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T14', 'Element 7177 7178', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T15', 'Element 7909 7910', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T16', 'Element 8267 8268', 'S']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T17', 'Element 10104 10105', 'P']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T22', 'Mineral 5926 5936', 'starkeyite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T23', 'Mineral 6527 6541', 'ferricopiapite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T24', 'Mineral 6546 6555', 'kornelite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T25', 'Mineral 6588 6598', 'starkeyite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T28', 'Mineral 7572 7579', 'sulfate']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1175.txt, ann=['T29', 'Mineral 8051 8059', 'sulfates']
# WARN: multiple starts at  1030 {1041: ['Mineral'], 1050: ['Mineral']}
# Chose: {1041: ['Mineral']}
# WARN: multiple starts at  1399 {1410: ['Mineral'], 1419: ['Mineral']}
# Chose: {1410: ['Mineral']}
# WARN: multiple starts at  6787 {6798: ['Mineral'], 6807: ['Mineral']}
# Chose: {6798: ['Mineral']}
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1241.txt, ann=['T1', 'Element 849 850', 'W']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1241.txt, ann=['T2', 'Element 7080 7081', 'I']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1241.txt, ann=['T3', 'Element 7415 7416', 'N']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/1291.txt, ann=['T4', 'Mineral 0 16', '1291.PDF']
# WARN: multiple starts at  7063 {7064: ['Element'], 7073: ['Mineral']}
# Chose: {7064: ['Element']}
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/2707.txt, ann=['T1', 'Element 2043 2044', 'N']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/2707.txt, ann=['T2', 'Mineral 6132 6143', 'labradorite']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/2707.txt, ann=['T3', 'Mineral 5496 5506', 'orthoclase']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/2774.txt, ann=['T10', 'Element 3827 3828', 'F']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/2774.txt, ann=['T11', 'Element 4033 4034', 'W']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/2774.txt, ann=['T12', 'Element 4084 4085', 'W']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/2774.txt, ann=['T13', 'Element 4154 4155', 'W']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/2774.txt, ann=['T14', 'Element 4493 4495', 'Ar']
# Error: Annotation mis-match, file=/Users/thammegr/work/mte/data/newcorpus/MTE-corpus-open/lpsc15-text/2774.txt, ann=['T15', 'Element 4964 4966', 'Ar']
# Dumped 1128 docs to mte-corpus-train.pickle
# WARN: multiple starts at  4059 {4060: ['Element'], 4069: ['Mineral']}
# Chose: {4060: ['Element']}
# WARN: multiple starts at  3558 {3565: ['Target'], 3574: ['Target']}
# WARN: multiple starts at  5083 {5097: ['Target'], 5091: ['Mineral']}
# Chose: {5091: ['Mineral']}
# WARN: multiple starts at  6878 {6892: ['Target'], 6886: ['Mineral']}
# Chose: {6886: ['Mineral']}
# WARN: multiple starts at  3124 {3140: ['Feature'], 3126: ['Element']}
# WARN: multiple starts at  6045 {6056: ['Mineral'], 6065: ['Mineral']}
# Chose: {6056: ['Mineral']}
# WARN: multiple starts at  6416 {6429: ['Material'], 6423: ['Element']}
# Chose: {6423: ['Element']}
# Dumped 20 docs to mte-corpus-dev.pickle
# WARN: multiple starts at  1737 {1753: ['Member'], 1746: ['Target']}
# Chose: {1746: ['Target']}
# WARN: multiple starts at  2375 {2384: ['Target'], 2391: ['Member']}
# Chose: {2384: ['Target']}
# WARN: multiple starts at  2981 {2993: ['Member'], 2989: ['Target']}
# Chose: {2989: ['Target']}
# WARN: multiple starts at  3367 {3379: ['Member'], 3375: ['Target']}
# Chose: {3375: ['Target']}
# WARN: multiple starts at  3911 {3923: ['Member'], 3919: ['Target']}
# Chose: {3919: ['Target']}
# WARN: multiple starts at  4773 {4785: ['Member'], 4781: ['Target']}
# Chose: {4781: ['Target']}
# WARN: multiple starts at  5197 {5209: ['Member'], 5205: ['Target']}
# Chose: {5205: ['Target']}
# WARN: multiple starts at  7694 {7696: ['Element'], 7721: ['Feature']}
# Chose: {7696: ['Element']}
# Dumped 35 docs to mte-corpus-test.pickle

# %% [markdown]
# ## Load the corpus
# Here we load the corpus from pickle file

# %%
corpus_file = 'mte-corpus-train.pickle'
corpus = pickle.load(open(corpus_file, 'rb'))
corpus[0][10]
# Out:
# [['Hollow', 'hollow', 'JJ', 'O'],
#  ['spherical', 'spherical', 'JJ', 'O'],
#  ['feature', 'feature', 'NN', 'O'],
#  ['observed', 'observe', 'VBN', 'O'],
#  ['on', 'on', 'IN', 'O'],
#  ['sol', 'sol', 'NN', 'O'],
#  ['122', '122', 'CD', 'O'],
#  ['in', 'in', 'IN', 'O'],
#  ['the', 'the', 'DT', 'O'],
#  ['Yellowknife', 'Yellowknife', 'NNP', 'O'],
#  ['Bay', 'Bay', 'NNP', 'O'],
#  ['area', 'area', 'NN', 'O'],
#  ['.', '.', '.', 'O']]

# %% [markdown]
# Next, we start playing with the features of CRF Suite to build a sequence tagger.

# %%
# %%time

def word2features(sent, idx):
    word = sent[idx]
    feats = [
        'word.bias',
        'word.lemma=' + word[1],
        'word.pos=' + word[2],
        'word.lower=' + word[0].lower(),
        'word[-3:]=' + word[0][-3:],
        'word[-2:]=' + word[0][-2:],
        'word.isupper=%s' % word[0].isupper(),
        'word.istitle=%s' % word[0].istitle(),
        'word.isdigit=%s' % word[0].isdigit(),
    ]
    if idx > 0:
        word = sent[idx-1]
        feats.extend([
            '-1:word.bias',
            '-1:word.lemma=' + word[1],
            '-1:word.pos=' + word[2],
            '-1:word.lower=' + word[0].lower(),
            '-1:word[-3:]=' + word[0][-3:],
            '-1:word[-2:]=' + word[0][-2:],
            '-1:word.isupper=%s' % word[0].isupper(),
            '-1:word.istitle=%s' % word[0].istitle(),
            '-1:word.isdigit=%s' % word[0].isdigit(),
        ])
    else:
        feats.append('BOS')
    if idx < len(sent) - 1:
        word = sent[idx + 1]
        feats.extend([
            '+1:word.bias',
            '+1:word.lemma=' + word[1],
            '+1:word.pos=' + word[2],
            '+1:word.lower=' + word[0].lower(),
            '+1:word[-3:]=' + word[0][-3:],
            '+1:word[-2:]=' + word[0][-2:],
            '+1:word.isupper=%s' % word[0].isupper(),
            '+1:word.istitle=%s' % word[0].istitle(),
            '+1:word.isdigit=%s' % word[0].isdigit(),
        ])
    else:
        feats.append('EOS')
    return feats

def seq2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def seq2labels(sent):
    return [tok[3] for tok in sent]

def merge_sequences(doc):
    '''
    document contains multiple sentences. here all sentences in document are merged to form one large sequence.
    '''
    res = []
    for seq in doc:
        res.extend(seq)
        res.append(['|', '|', '|', 'O']) # sentence end marker
    return res
    
trainer = pycrfsuite.Trainer(verbose=False)
for doc in corpus:
    seq = merge_sequences(doc)
    x_seq = seq2features(seq)
    y_seq = seq2labels(seq)
    trainer.append(x_seq, y_seq)

trainer.set_params({
    'c1': 0.5,   # coefficient for L1 penalty
    'c2': 1e-3,  # coefficient for L2 penalty
    'max_iterations': 50,  # stop earlier
    # include transitions that are possible, but not observed
    'feature.possible_transitions': True
})

print(trainer.params())
model_file = 'jpl-mars-target-ner-model.crfsuite'
trainer.train(model_file)
print("Training Done")

# !ls -alh 'jpl-mars-target-ner-model.crfsuite'
trainer.logparser.last_iteration
# Out:
# ['feature.minfreq', 'feature.possible_states', 'feature.possible_transitions', 'c1', 'c2', 'max_iterations', 'num_memories', 'epsilon', 'period', 'delta', 'linesearch', 'max_linesearch']
# Training Done
# -rw-r--r--  1 thammegr  703763885   214K Feb 15 16:53 jpl-mars-target-ner-model.crfsuite
# CPU times: user 2min 18s, sys: 1.08 s, total: 2min 19s
# Wall time: 2min 19s

# %% [markdown]
# # Using the model to predict

# %%
tagger = pycrfsuite.Tagger()
tagger.open(model_file)
doc = corpus[20]
seq = merge_sequences(doc)

y = seq2labels(seq)
y_ = tagger.tag(seq2features(seq))

c = 0
for a,p, tok in zip(y,y_, seq):
    #if a != 'O' and p != 'O':
    if a != p:
        print(a,p,tok)
        c += 1
print(c)
# Out:
# B-Target O ['Shoemaker', 'Shoemaker', 'NNP', 'B-Target']
# 1

# %% [markdown]
# # Evaluate

# %%
def bio_classification_report(y_true, y_pred):
    """
    Classification report for a list of BIO-encoded sequences.
    It computes token-level metrics and discards "O" labels.
    
    Note that it requires scikit-learn 0.15+ (or a version from github master)
    to calculate averages properly!
    """
    lb = LabelBinarizer()
    y_true_combined = lb.fit_transform(list(chain.from_iterable(y_true)))
    y_pred_combined = lb.transform(list(chain.from_iterable(y_pred)))
        
    tagset = set(lb.classes_) - {'O'}
    tagset = sorted(tagset, key=lambda tag: tag.split('-', 1)[::-1])
    #tagset.append('O')
    class_indices = {cls: idx for idx, cls in enumerate(lb.classes_)}
    
    return classification_report(
        y_true_combined,
        y_pred_combined,
        labels = [class_indices[cls] for cls in tagset],
        target_names = tagset,
    )

def evaluate(tagger, corpus_file):    
    corpus = pickle.load(open(corpus_file, 'rb'))
    y_pred = []
    y_true = []
    for doc in corpus:
        seq = merge_sequences(doc)
        y_true.append(seq2labels(seq))
        y_pred.append(tagger.tag(seq2features(seq)))
    return bio_classification_report(y_true, y_pred)

print(evaluate(tagger, dev_corpus_file))
print(evaluate(tagger, test_corpus_file))
# Out:
#              precision    recall  f1-score   support
#
#    B-Target       0.95      0.24      0.39       147
#    I-Target       0.88      0.50      0.64        14
#
# avg / total       1.00      1.00      1.00     34970
#
#              precision    recall  f1-score   support
#
#    B-Target       0.95      0.30      0.46       194
#    I-Target       1.00      0.35      0.52        20
#
# avg / total       1.00      1.00      1.00     60630

# %% [markdown]
# # Learning: State Transitions

# %%
from collections import Counter
info = tagger.info()

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

print("Top likely transitions:")
print_transitions(Counter(info.transitions).most_common(15))

print("\nTop unlikely transitions:")
print_transitions(Counter(info.transitions).most_common()[-15:])
# Out:
# Top likely transitions:
# B-Target -> I-Target 2.317607
# I-Target -> I-Target 1.922520
# O      -> O       1.387535
# B-Target -> B-Target 1.191201
# I-Target -> B-Target 1.121970
# I-Target -> O       -0.366761
# O      -> B-Target -0.370077
# B-Target -> O       -2.414795
# O      -> I-Target -6.240270
#
# Top unlikely transitions:
# B-Target -> I-Target 2.317607
# I-Target -> I-Target 1.922520
# O      -> O       1.387535
# B-Target -> B-Target 1.191201
# I-Target -> B-Target 1.121970
# I-Target -> O       -0.366761
# O      -> B-Target -0.370077
# B-Target -> O       -2.414795
# O      -> I-Target -6.240270

# %% [markdown]
# # Learning: State Features

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-6s %s" % (weight, label, attr))    

print("Top positive:")
print_state_features(Counter(info.state_features).most_common(20))

print("\nTop negative:")
print_state_features(Counter(info.state_features).most_common()[-20:])
# Out:
# Top positive:
# 10.330524 B-Target lemma=bonanza_king
# 9.577672 B-Target lemma=windjana
# 8.777970 B-Target lemma=Chinle
# 8.748215 B-Target lemma=epworth_5
# 8.467253 B-Target lemma=Winnipesaukee
# 8.425027 B-Target lemma=stovepipe_wells
# 8.273857 B-Target lemma=mondooma
# 7.867740 B-Target lemma=perdido2
# 7.620713 B-Target lemma=Tappers
# 7.592996 B-Target lemma=rocknest3
# 7.560412 B-Target lemma=Epworth
# 7.324442 B-Target lemma=epworth-5
# 7.252722 B-Target lemma=blackhead_7
# 7.207652 B-Target lemma=square_top
# 7.067435 B-Target lemma=yarrada
# 7.053535 B-Target lemma=Bathurst
# 6.935831 B-Target lemma=Kilian
# 6.654012 B-Target lemma=Methuselah
# 6.568420 B-Target lemma=Green_Head
# 6.448084 B-Target lemma=Pinnacle
#
# Top negative:
# -3.421099 O      lemma=Stark
# -3.428704 O      lemma=Watchtower
# -3.441445 O      lemma=rocknest3_3
# -3.552088 O      lemma=Harrison
# -3.670150 O      lemma=Darwin
# -3.726463 O      +1]lemma=class
# -4.053420 O      lemma=Comanche
# -4.124759 O      lemma=Cumberland
# -4.191936 O      lemma=RN
# -4.265565 O      lemma=Sheepbed
# -4.388925 O      lemma=Jake
# -4.536981 O      lemma=ch
# -4.640433 O      lemma=rocknest
# -4.764755 O      lemma=JK
# -4.969287 O      lemma=CB
# -5.140690 O      lemma=cb
# -5.293370 O      lemma=rn
# -5.347160 O      lemma=cumberland
# -5.652117 O      lemma=Windjana
# -5.749805 O      lemma=sheepbed

# %%
# Out:
# False
